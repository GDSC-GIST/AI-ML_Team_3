# %% [markdown]
# # info
# - by: LeeHaEun
# - start: 21.11.08 Mon
# - end: 21.11.08 Mon
# - review: 21.11.08 Mon

# %% [markdown]
# # 개념
# `Artificial Intelligence`: A field of computer science that aims to make **computers** achieve **human-style** intelligence.
#
# `Machine Learning`: A set of related techniques in which computers are trained to perform a **particular task** rather than by explicitly **programming them.**
#
# `Neural Network`: A construct in Machine Learning inspired by the network of neurons (nerve cells) in the biological brain.
#
# `Deep Learning`: A subfield of machine learning that uses **multi-layered neural networks.**

# %% [markdown]
# # code

# %% [markdown]
# ## format()

# %%
for i in range(8, 25, 5):  # i=8, 13, 18, 23 (start, stop, step)
  print("--- Now running with i: {}".format(i))
  r = HelloWorldXY(i,i)
  print("Result from HelloWorld: {}".format(r))

# %% [markdown]
# & 대신에 .format() 사용

# %% [markdown]
# ## numpy

# %%
import numpy as np  # Make numpy available using np.

# Create a numpy array, and append an element
a = np.array(["Hello", "World"])
a = np.append(a, "!")
print("Current array: {}".format(a))
print("Printing each element")
for i in a:
  print(i)

print("\nPrinting each element and their index")
for i,e in enumerate(a):
  print("Index: {}, was: {}".format(i, e))

# %% [markdown]
# - **numpy** library import
# - numpy.append(리스트, "붙일 문자열")
# - numpy.enumerate(리스트)
#   return i(인덱스), val(값)

# %% [markdown]
# ## type()

# %%
  print("\nYou can print the type of anything")
  print("Type of b: {}, type of b[0]: {}".format(type(b), type(b[0])))

# %% [markdown]
# ## colab special

# %%
# !pwd

# %% [markdown]
# print working directory
